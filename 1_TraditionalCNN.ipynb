# %%
#CNN ############################

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard, CSVLogger
from tensorflow.keras.metrics import Precision, Recall, F1Score
import tensorflow.keras.backend as K

train_dir = "C:/Users/ugur-/Desktop/FinalDatas/train"
test_dir = "C:/Users/ugur-/Desktop/FinalDatas/test"

model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48,1)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
    
model.add(Conv2D(512,(3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(512,(3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
    
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))

img_size=48

train_datagen = ImageDataGenerator(width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)

train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                             )

def f1_score(y_true, y_pred):
    # True pozitifleri hesapla
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Olası pozitif tahminleri hesapla
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Tahmin edilen pozitifleri hesapla
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision ve recall hesapla
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    # F1 Skorunu hesapla
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall'), f1_score]
)


epochs = 45
batch_size = 64

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1)
]
# Model eğitimi
history = model.fit(
    x=train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=callbacks
)

# Save the entire model to a HDF5 file.
model.save('grafikmodel2.h5')

# Save the weights of the model as a HDF5 file.
model.save_weights('grafikmodel2.weights.h5')

model.summary()


fig, ax = plt.subplots(5, 1, figsize=(10, 25))  # Beş grafik için dikey subplot ayarları

# Doğruluk ve Kayıp Grafikleri
ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training and Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training and Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

# Precision ve Recall Grafikleri
ax[2].plot(history.history['precision'])
ax[2].plot(history.history['val_precision'])
ax[2].set_title('Training and Validation Precision')
ax[2].set_ylabel('Precision')
ax[2].set_xlabel('Epoch')
ax[2].legend(['Train', 'Validation'], loc='upper left')

ax[3].plot(history.history['recall'])
ax[3].plot(history.history['val_recall'])
ax[3].set_title('Training and Validation Recall')
ax[3].set_ylabel('Recall')
ax[3].set_xlabel('Epoch')
ax[3].legend(['Train', 'Validation'], loc='upper left')

# F1 Score Grafik
ax[4].plot(history.history['f1_score'])
ax[4].plot(history.history['val_f1_score'])
ax[4].set_title('Training and Validation F1 Score')
ax[4].set_ylabel('F1 Score')
ax[4].set_xlabel('Epoch')
ax[4].legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# C:\Users\ugur-\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.
# Epoch 1/45
# C:\Users\ugur-\AppData\Roaming\Python\Python39\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.2108 - f1_score: 0.0994 - loss: 2.2672 - precision: 0.2233 - recall: 0.0649
# Epoch 1: val_accuracy improved from -inf to 0.17109, saving model to best_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 231s 629ms/step - accuracy: 0.2108 - f1_score: 0.0994 - loss: 2.2666 - precision: 0.2234 - recall: 0.0649 - val_accuracy: 0.1711 - val_f1_score: 0.1745 - val_loss: 4.0925 - val_precision: 0.1714 - val_recall: 0.1711 - learning_rate: 0.0010
# Epoch 2/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.3256 - f1_score: 0.1893 - loss: 1.7507 - precision: 0.4969 - recall: 0.1181
# Epoch 2: val_accuracy improved from 0.17109 to 0.40154, saving model to best_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 170s 472ms/step - accuracy: 0.3256 - f1_score: 0.1894 - loss: 1.7506 - precision: 0.4971 - recall: 0.1181 - val_accuracy: 0.4015 - val_f1_score: 0.2252 - val_loss: 1.5874 - val_precision: 0.7208 - val_recall: 0.1334 - learning_rate: 0.0010
# Epoch 3/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.4047 - f1_score: 0.2931 - loss: 1.5536 - precision: 0.6281 - recall: 0.1927
# Epoch 3: val_accuracy improved from 0.40154 to 0.42318, saving model to best_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 178s 494ms/step - accuracy: 0.4048 - f1_score: 0.2932 - loss: 1.5535 - precision: 0.6281 - recall: 0.1927 - val_accuracy: 0.4232 - val_f1_score: 0.3736 - val_loss: 1.6379 - val_precision: 0.5478 - val_recall: 0.2842 - learning_rate: 0.0010
# Epoch 4/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.4830 - f1_score: 0.3892 - loss: 1.3531 - precision: 0.6923 - recall: 0.2718
# Epoch 4: val_accuracy improved from 0.42318 to 0.51327, saving model to best_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 169s 470ms/step - accuracy: 0.4830 - f1_score: 0.3892 - loss: 1.3531 - precision: 0.6923 - recall: 0.2718 - val_accuracy: 0.5133 - val_f1_score: 0.4256 - val_loss: 1.2657 - val_precision: 0.7270 - val_recall: 0.3031 - learning_rate: 0.0010
# Epoch 5/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.5062 - f1_score: 0.4288 - loss: 1.2755 - precision: 0.7134 - recall: 0.3077
# Epoch 5: val_accuracy improved from 0.51327 to 0.54120, saving model to best_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 162s 451ms/step - accuracy: 0.5062 - f1_score: 0.4288 - loss: 1.2755 - precision: 0.7134 - recall: 0.3078 - val_accuracy: 0.5412 - val_f1_score: 0.5077 - val_loss: 1.2050 - val_precision: 0.6767 - val_recall: 0.4064 - learning_rate: 0.0010
# Epoch 6/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 40: val_accuracy did not improve from 0.66969
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 160s 446ms/step - accuracy: 0.7260 - f1_score: 0.7153 - loss: 0.7256 - precision: 0.8035 - recall: 0.6453 - val_accuracy: 0.6676 - val_f1_score: 0.6581 - val_loss: 0.9432 - val_precision: 0.7330 - val_recall: 0.6020 - learning_rate: 4.0000e-05
# Epoch 41/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7308 - f1_score: 0.7195 - loss: 0.7142 - precision: 0.8065 - recall: 0.6505
# Epoch 41: val_accuracy did not improve from 0.66969
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 161s 448ms/step - accuracy: 0.7308 - f1_score: 0.7195 - loss: 0.7143 - precision: 0.8065 - recall: 0.6505 - val_accuracy: 0.6648 - val_f1_score: 0.6570 - val_loss: 0.9445 - val_precision: 0.7255 - val_recall: 0.5999 - learning_rate: 1.0000e-05
# Epoch 42/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.7246 - f1_score: 0.7124 - loss: 0.7350 - precision: 0.8023 - recall: 0.6415
# Epoch 42: val_accuracy did not improve from 0.66969
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 161s 448ms/step - accuracy: 0.7246 - f1_score: 0.7124 - loss: 0.7350 - precision: 0.8023 - recall: 0.6416 - val_accuracy: 0.6662 - val_f1_score: 0.6666 - val_loss: 0.9437 - val_precision: 0.7314 - val_recall: 0.6027 - learning_rate: 1.0000e-05
# Epoch 43/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7268 - f1_score: 0.7154 - loss: 0.7303 - precision: 0.8035 - recall: 0.6458
# Epoch 43: val_accuracy did not improve from 0.66969
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 161s 448ms/step - accuracy: 0.7268 - f1_score: 0.7155 - loss: 0.7303 - precision: 0.8035 - recall: 0.6458 - val_accuracy: 0.6627 - val_f1_score: 0.6557 - val_loss: 0.9427 - val_precision: 0.7304 - val_recall: 0.5999 - learning_rate: 1.0000e-05
# Epoch 44/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.7322 - f1_score: 0.7163 - loss: 0.7215 - precision: 0.8033 - recall: 0.6475
# Epoch 44: val_accuracy did not improve from 0.66969
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 161s 447ms/step - accuracy: 0.7322 - f1_score: 0.7163 - loss: 0.7215 - precision: 0.8033 - recall: 0.6475 - val_accuracy: 0.6641 - val_f1_score: 0.6574 - val_loss: 0.9443 - val_precision: 0.7295 - val_recall: 0.6027 - learning_rate: 1.0000e-05
# Epoch 45/45
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.7299 - f1_score: 0.7196 - loss: 0.7139 - precision: 0.8073 - recall: 0.6503
# Epoch 45: val_accuracy did not improve from 0.66969
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 161s 447ms/step - accuracy: 0.7299 - f1_score: 0.7196 - loss: 0.7139 - precision: 0.8073 - recall: 0.6503 - val_accuracy: 0.6627 - val_f1_score: 0.6593 - val_loss: 0.9444 - val_precision: 0.7310 - val_recall: 0.6034 - learning_rate: 1.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,482,775 (51.43 MB)
#  Trainable params: 4,492,935 (17.14 MB)
#  Non-trainable params: 3,968 (15.50 KB)
#  Optimizer params: 8,985,872 (34.28 MB)
